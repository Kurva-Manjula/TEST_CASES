# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # how to read csv file?

# %%
pm=pd.read_csv("C:/Users/admin/Downloads/Pokemon.csv")

# %%
pm
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # find 1st & last 5 rows ?

# %%
pm.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pm.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# # check the columns for Data Frame?

# %%
pm.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# # Check the shape of the DataFrame (rows, columns)?

# %%
pm.shape
# Out:
# (800, 13)

# %% [markdown]
# # check statistical information about the dataframe?

# %%
pm.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# # How many Pokémon are legendary?

# %%
legendary_pm=pm['Legendary'].value_counts()

# %%
legendary_pm
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %% [markdown]
# # Legendary Pokémon by type?

# %%
legendary_by_type=pm[pm['Legendary']==True].groupby('Type 1').size()

# %%
legendary_by_type
# Out:
# Type 1
# Dark         2
# Dragon      12
# Electric     4
# Fairy        1
# Fire         5
# Flying       2
# Ghost        2
# Grass        3
# Ground       4
# Ice          2
# Normal       2
# Psychic     14
# Rock         4
# Steel        4
# Water        4
# dtype: int64

# %%
legendary_by_type=pm[pm['Legendary']==True].groupby('Type 2').size()

# %%
legendary_by_type
# Out:
# Type 2
# Dark         1
# Dragon       4
# Electric     1
# Fairy        2
# Fighting     4
# Fire         3
# Flying      13
# Ghost        1
# Ground       1
# Ice          3
# Psychic      5
# Steel        1
# Water        1
# dtype: int64

# %% [markdown]
# # Legendary Pokémon by fighter stats?

# %%
fighter_stats=pm[(pm['Legendary'])][['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']]

# %%
fighter_stats
# Out:
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 156   90      85      100       95      125     85
# 157   90      90       85      125       90    100
# 158   90     100       90      125       85     90
# 162  106     110       90      154       90    130
# 163  106     190      100      154      100    130
# ..   ...     ...      ...      ...      ...    ...
# 795   50     100      150      100      150     50
# 796   50     160      110      160      110    110
# 797   80     110       60      150      130     70
# 798   80     160       60      170      130     80
# 799   80     110      120      130       90     70
#
# [65 rows x 6 columns]

# %% [markdown]
# # Cleaning the dataset?

# %%
pm.fillna("NA",inplace=True)

# %%
pm
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire      NA    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # How are Pokemon numbers distributed across generations?

# %%
pm_distribution=pm.groupby('Generation').size()

# %%
pm_distribution
# Out:
# Generation
# 1    166
# 2    106
# 3    160
# 4    121
# 5    165
# 6     82
# dtype: int64

# %% [markdown]
# # What are the most common types of Pokemon?

# %%
pm_types=pm['Type 1'].value_counts()

# %%
print(pm_types.head())
# Out:
# Water      112
# Normal      98
# Grass       70
# Bug         69
# Psychic     57
# Name: Type 1, dtype: int64

# %%
pm_types=pm['Type 2'].value_counts()

# %%
print(pm_types.head())
# Out:
# NA         386
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Name: Type 2, dtype: int64

# %% [markdown]
# # What are the strongest and weakest Pokemon species?

# %%
strongest_pm=pm.sort_values(by='Total',ascending=False).head()

# %%
strongest_pm
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 164  150    MewtwoMega Mewtwo Y  Psychic        NA    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 422  382    KyogrePrimal Kyogre    Water        NA    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 426      100      180      100    115           3       True
# 164       70      194      120    140           1       True
# 163      100      154      100    130           1       True
# 422       90      180      160     90           3       True
# 424      160      150       90     90           3       True

# %%
weakest_pm=pm.sort_values(by='Total',ascending=True).head()

# %%
weakest_pm
# Out:
#        #       Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 206  191    Sunkern   Grass      NA    180  30      30       30       30
# 322  298    Azurill  Normal   Fairy    190  50      20       40       20
# 446  401  Kricketot     Bug      NA    194  37      25       41       25
# 288  265    Wurmple     Bug      NA    195  45      45       35       20
# 16    13     Weedle     Bug  Poison    195  40      35       30       20
#
#      Sp. Def  Speed  Generation  Legendary
# 206       30     30           2      False
# 322       40     20           3      False
# 446       41     25           4      False
# 288       30     20           3      False
# 16        20     50           1      False

# %% [markdown]
# # What are the strongest and weakest types of Pokemon?

# %%
strongest_type=pm.groupby('Type 1')['Total'].max()

# %%
strongest_type
# Out:
# Type 1
# Bug         600
# Dark        680
# Dragon      780
# Electric    610
# Fairy       680
# Fighting    625
# Fire        680
# Flying      580
# Ghost       680
# Grass       630
# Ground      770
# Ice         580
# Normal      720
# Poison      535
# Psychic     780
# Rock        700
# Steel       700
# Water       770
# Name: Total, dtype: int64

# %%
weakest_type=pm.groupby('Type 2')['Total'].max()

# %%
weakest_type
# Out:
# Type 2
# Bug         495
# Dark        700
# Dragon      680
# Electric    680
# Fairy       700
# Fighting    780
# Fire        770
# Flying      780
# Ghost       600
# Grass       600
# Ground      700
# Ice         700
# NA          780
# Normal      507
# Poison      625
# Psychic     700
# Rock        535
# Steel       625
# Water       600
# Name: Total, dtype: int64

# %% [markdown]
# # Do any types of Pokemon excel at certain statistics over others?

# %% [markdown]
# # Are any of the statistics correlated?

# %%
columns=['Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']

# %%
correlation_matrix=pm[columns].corr()

# %%
correlation_matrix
# Out:
#             Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# Total    1.000000  0.618748  0.736211  0.612787  0.747250  0.717609  0.575943
# HP       0.618748  1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.736211  0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.612787  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.747250  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.717609  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.575943  0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %% [markdown]
# # Create a training/test split?

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data=train_test_split(pm,test_size=0.2,random_state=42)

# %%
print('Train data shape:',train_data.shape)
# Out:
# Train data shape: (640, 13)

# %%
print('Test data shape:',test_data.shape)
# Out:
# Test data shape: (160, 13)

# %% [markdown]
# # split data int Train and model sets?

# %%
train_data,model_data=train_test_split(pm,test_size=0.2,random_state=42)

# %%
print('Train data shape:',train_data.shape)
# Out:
# Train data shape: (640, 13)

# %%
print('Model data shape:',model_data.shape)
# Out:
# Model data shape: (160, 13)
