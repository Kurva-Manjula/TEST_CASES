# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/admin/Downloads/12.real state.csv")

# %%
df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %% [markdown]
# # Find City wise list all the Villa which is not less than ten thousand?

# %%
fil_data=df[df['price']>=10000]

# %%
city_wise_list=fil_data.groupby('city')['street'].apply(list)

# %%
city_wise_list
# Out:
# city
# ANTELOPE           [3828 BLACKFOOT WAY, 5708 RIDGEPOINT DR, 4844 ...
# AUBURN             [1740 HIGH ST, 2231 COUNTRY VILLA CT, 220 OLD ...
# CAMERON PARK       [2778 KAWEAH CT, 3361 BOW MAR CT, 3429 FERNBRO...
# CARMICHAEL         [5332 SANDSTONE ST, 5907 ELLERSLEE DR, 4010 AL...
# CITRUS HEIGHTS     [6236 LONGFORD DR Unit 1, 6118 STONEHAND AVE, ...
# COOL                                           [2341 BIG STRIKE TRL]
# DIAMOND SPRINGS                                   [636 CRESTVIEW DR]
# EL DORADO                   [4885 SUMMIT VIEW DR, 6320 EL DORADO ST]
# EL DORADO HILLS    [3020 RICHARDSON CIR, 6030 PALERMO WAY, 4070 R...
# ELK GROVE          [5201 LAGUNA OAKS DR Unit 140, 5201 LAGUNA OAK...
# ELVERTA            [7944 DOMINION WAY, 2505 RHINE WAY, 7741 MILLD...
# FAIR OAKS          [5333 PRIMROSE DR Unit 19A, 8164 CHENIN BLANC ...
# FOLSOM             [120 GRANT LN, 100 REBECCA WAY, 207 ORANGE BLO...
# ...

# %% [markdown]
# # In GALT city which residential type has more than 800sq__ft. Display their respective details street,sq__ft,sale_date,city?

# %%
fil_df=df[df['sq__ft']>800]

# %%
fil_df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 5     5828 PEPPERMILL CT       SACRAMENTO  95841    CA     3      1    1122
# 6    6048 OGDEN NASH WAY       SACRAMENTO  95842    CA     3      2    1104
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
fil_df[['street','sq__ft','sale_date','city']]
# Out:
#                   street  sq__ft                     sale_date  \
# 0           3526 HIGH ST     836  Wed May 21 00:00:00 EDT 2008
# 1            51 OMAHA CT    1167  Wed May 21 00:00:00 EDT 2008
# 3       2805 JANETTE WAY     852  Wed May 21 00:00:00 EDT 2008
# 5     5828 PEPPERMILL CT    1122  Wed May 21 00:00:00 EDT 2008
# 6    6048 OGDEN NASH WAY    1104  Wed May 21 00:00:00 EDT 2008
# ..                   ...     ...                           ...
# 980   9169 GARLINGTON CT    2280  Thu May 15 00:00:00 EDT 2008
# 981      6932 RUSKUT WAY    1477  Thu May 15 00:00:00 EDT 2008
# 982    7933 DAFFODIL WAY    1216  Thu May 15 00:00:00 EDT 2008
# 983     8304 RED FOX WAY    1685  Thu May 15 00:00:00 EDT 2008
# 984  3882 YELLOWSTONE LN    1362  Thu May 15 00:00:00 EDT 2008
#
#                 city
# 0         SACRAMENTO
# 1         SACRAMENTO
# 3         SACRAMENTO
# 5         SACRAMENTO
# 6         SACRAMENTO
# ..               ...
# 980       SACRAMENTO
# 981       SACRAMENTO
# ...

# %% [markdown]
# # Which is the cheapest Villa in CA. name the city,street and price for the Villa.

# %%
fil_df=df[df['type']=='Villa']
cheapest_villa=fil_df.sort_values('price')

# %%
city=cheapest_villa['city']

# %%
city
# Out:
# Series([], Name: city, dtype: object)

# %%
street=cheapest_villa['street']

# %%
price=cheapest_villa['price']

# %%
f"The chepest villa in california is located in{city},at{street},with a price of{price}."
# Out:
# 'The chepest villa in california is located inSeries([], Name: city, dtype: object),atSeries([], Name: street, dtype: object),with a price ofSeries([], Name: price, dtype: int64).'

# %% [markdown]
# # List top 5 residency details which lie in the budget of 60000-120000, an area more than 1450, min bedroom 3 and, min bathroom 2?

# %%
fil_df=df[(df['price']>=60000)&(df['price']<=120000)&
(df['sq__ft']>1450)&(df['beds']>=3)&(df['baths']>=2)]

# %%
top_5_df=fil_df.nsmallest(5,'price')

# %%
top_5_df
# Out:
#             city  baths  sq__ft  price         type  beds
# 865      LINCOLN      3       0   1551  Residential     3
# 866  SLOUGHHOUSE      4    5822   2000  Residential     3
# 579      LINCOLN      2       0   4897  Residential     4
# 580      LINCOLN      2       0   4897  Residential     3
# 581      LINCOLN      2       0   4897  Residential     3

# %% [markdown]
# # separate list of residential apartments with more than 2 beds. Also include columns in following order City,Baths,Sq_feet,Price,flat_type,Beds respectively.

# %%
fil_df=df[df['beds']>2]

# %%
fil_df=fil_df[['city','baths','sq__ft','price','type','beds']]

# %%
fil_df
# Out:
#                 city  baths  sq__ft   price         type  beds
# 1         SACRAMENTO      1    1167   68212  Residential     3
# 5         SACRAMENTO      1    1122   89921        villa     3
# 6         SACRAMENTO      2    1104   90895  Residential     3
# 7         SACRAMENTO      1    1177   91002  Residential     3
# 9          RIO LINDA      2    1146   98937  Residential     3
# ..               ...    ...     ...     ...          ...   ...
# 980       SACRAMENTO      3    2280  232425  Residential     4
# 981       SACRAMENTO      2    1477  234000  Residential     3
# 982   CITRUS HEIGHTS      2    1216  235000  Residential     3
# 983        ELK GROVE      2    1685  235301  Residential     4
# 984  EL DORADO HILLS      2    1362  235738  Residential     3
#
# [734 rows x 6 columns]
